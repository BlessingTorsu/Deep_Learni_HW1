# %%
### IMport libraries
import numpy as np
import tqdm
import copy
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision.datasets import MNIST
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
import math
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from PIL import Image
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define transformations for the data
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))])

# Hyper-parameters
input_size = 784 # 28x28
batch_size = 64


# Load the dataset
train_dataset = MNIST(root='./data', train=True, transform=transform, download=True)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = MNIST(root='./data', train=False, transform=transform, download=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
torch.manual_seed(124)

# %% [markdown]
# **Define ten DNN models**

# %%
## Model 1
class Model1(nn.Module):
    def __init__(self):
        super(Model1, self).__init__()
        self.fc1 = nn.Linear(input_size, 5)
        self.fc2 = nn.Linear(5, 10)
        self.fc3 = nn.Linear(10, 10)

    def forward(self, x):
        x = x.view(-1, input_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x



## Model 2
class Model2(nn.Module):
    def __init__(self):
        super(Model2, self).__init__()
        self.fc1 = nn.Linear(input_size, 10)
        self.fc2 = nn.Linear(10, 20)
        self.fc3 = nn.Linear(20, 10)

    def forward(self, x):
        x = x.view(-1, input_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


## Model 3
class Model3(nn.Module):
    def __init__(self):
        super(Model3, self).__init__()
        self.fc1 = nn.Linear(input_size, 12)
        self.fc2 = nn.Linear(12, 24)
        self.fc3 = nn.Linear(24, 10)

    def forward(self, x):
        x = x.view(-1, input_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

## Model 4
class Model4(nn.Module):
    def __init__(self):
        super(Model4, self).__init__()
        self.fc1 = nn.Linear(input_size, 18)
        self.fc2 = nn.Linear(18, 34)
        self.fc3 = nn.Linear(34, 10)

    def forward(self, x):
        x = x.view(-1, input_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


## Model 5
class Model5(nn.Module):
    def __init__(self):
        super(Model5, self).__init__()
        self.fc1 = nn.Linear(input_size, 20)
        self.fc2 = nn.Linear(20, 25)
        self.fc3 = nn.Linear(25, 10)

    def forward(self, x):
        x = x.view(-1, input_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

## Model 6
class Model6(nn.Module):
    def __init__(self):
        super(Model6, self).__init__()
        self.fc1 = nn.Linear(input_size, 25)
        self.fc2 = nn.Linear(25, 32)
        self.fc3 = nn.Linear(32, 10)

    def forward(self, x):
        x = x.view(-1, input_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

## Model 7
class Model7(nn.Module):
    def __init__(self):
        super(Model7, self).__init__()
        self.fc1 = nn.Linear(input_size, 32)
        self.fc2 = nn.Linear(32, 40)
        self.fc3 = nn.Linear(40, 10)

    def forward(self, x):
        x = x.view(-1, input_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

## Model 8
class Model8(nn.Module):
    def __init__(self):
        super(Model8, self).__init__()
        self.fc1 = nn.Linear(input_size, 42)
        self.fc2 = nn.Linear(42, 64)
        self.fc3 = nn.Linear(64, 10)

    def forward(self, x):
        x = x.view(-1, input_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


## Model 9
class Model9(nn.Module):
    def __init__(self):
        super(Model9, self).__init__()
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 128)
        self.fc3 = nn.Linear(128, 10)

    def forward(self, x):
        x = x.view(-1, input_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

## Model 10
class Model10(nn.Module):
    def __init__(self):
        super(Model10, self).__init__()
        self.fc1 = nn.Linear(input_size, 80)
        self.fc2 = nn.Linear(80, 128)
        self.fc3 = nn.Linear(128, 10)

    def forward(self, x):
        x = x.view(-1, input_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def train_model(model, optimizer, train_loader, criterion):
    model.train()

    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()

        # Forward propagation
        output = model(data.view(-1, 784))
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

# %%
def loss_model(model, loader, criterion):
    correct = 0
    total = 0
    costTotal = 0
    costCounter = 0
    with torch.no_grad():
        for batch in loader:
            data, target = batch
            output = model(data.view(-1, 784))
            cost = criterion(output, target)
            costTotal += cost
            costCounter += 1
            for i, outputTensor in enumerate(output):
                if torch.argmax(outputTensor) == target[i]:
                    correct += 1
                total += 1
        tl = costTotal / costCounter
        acu =round(correct/total, 3)
    return tl,acu

# %%
n_epo = 5
train_losses = []
test_losses = []
train_accuracies = []
test_accuracies = []
def train_test_model(model, optimizer):
    criterion = torch.nn.CrossEntropyLoss()
    for epoch in range(n_epo):
        train_model(model, optimizer, train_loader, criterion)
        train_loss, train_acc = loss_model(model, train_loader, criterion)
        test_loss, test_acc = loss_model(model, test_loader, criterion)
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)
    print(f" Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}")

# %%
###  Model 1
model1 = Model1()
criterion = nn.CrossEntropyLoss()
optimizer1 = optim.Adam(model1.parameters(), lr = 1e-3, weight_decay = 1e-4)
model1_params = sum(p.numel() for p in model1.parameters())
print(f'Nunber of parameter for model 1 is: {model1_params}')
train_test_model(model1, optimizer1)

# %%
train_losses

# %%
###  Model 1
model1 = Model1()
criterion = nn.CrossEntropyLoss()
optimizer1 = optim.Adam(model1.parameters(), lr = 1e-3, weight_decay = 1e-4)
model1_params = sum(p.numel() for p in model1.parameters())
print(f'Nunber of parameter for model 1 is: {model1_params}')
train_test_model(model1, optimizer1)


###  Model 2
model2 = Model2()
criterion = nn.CrossEntropyLoss()
optimizer2 = optim.Adam(model2.parameters(), lr = 1e-3, weight_decay = 1e-4)
model2_params = sum(p.numel() for p in model2.parameters())
print(f'Nunber of parameter for model 2 is: {model2_params}')
train_test_model(model2, optimizer2)


###  Model 3
model3 = Model3()
criterion = nn.CrossEntropyLoss()
optimizer3 = optim.Adam(model3.parameters(), lr = 1e-3, weight_decay = 1e-4)
model3_params = sum(p.numel() for p in model3.parameters())
print(f'Nunber of parameter for model 3 is: {model3_params}')
train_test_model(model3, optimizer3)

###  Model 4
model4 = Model4()
criterion = nn.CrossEntropyLoss()
optimizer4 = optim.Adam(model4.parameters(), lr = 1e-3, weight_decay = 1e-4)
model4_params = sum(p.numel() for p in model4.parameters())
print(f'Nunber of parameter for model 4 is: {model4_params}')
train_test_model(model4, optimizer4)

###  Model 5
model5 = Model5()
criterion = nn.CrossEntropyLoss()
optimizer5 = optim.Adam(model5.parameters(), lr = 1e-3, weight_decay = 1e-4)
model5_params = sum(p.numel() for p in model5.parameters())
print(f'Nunber of parameter for model 5 is: {model5_params}')
train_test_model(model5, optimizer5)

###  Model 6
model6 = Model6()
criterion = nn.CrossEntropyLoss()
optimizer6 = optim.Adam(model6.parameters(), lr = 1e-3, weight_decay = 1e-4)
model6_params = sum(p.numel() for p in model6.parameters())
print(f'Nunber of parameter for model 6 is: {model6_params}')
train_test_model(model6, optimizer6)

###  Model 7
model7 = Model7()
criterion = nn.CrossEntropyLoss()
optimizer7 = optim.Adam(model7.parameters(), lr = 1e-3, weight_decay = 1e-4)
model7_params = sum(p.numel() for p in model7.parameters())
print(f'Nunber of parameter for model 7 is: {model7_params}')
train_test_model(model7, optimizer7)

###  Model 8
model8 = Model8()
criterion = nn.CrossEntropyLoss()
optimizer8 = optim.Adam(model8.parameters(), lr = 1e-3, weight_decay = 1e-4)
model8_params = sum(p.numel() for p in model8.parameters())
print(f'Nunber of parameter for model 8 is: {model8_params}')
train_test_model(model8, optimizer8)

###  Model 9
model9 = Model9()
criterion = nn.CrossEntropyLoss()
optimizer9 = optim.Adam(model9.parameters(), lr = 1e-3, weight_decay = 1e-4)
model9_params = sum(p.numel() for p in model9.parameters())
print(f'Nunber of parameter for model 9 is: {model9_params}')
train_test_model(model9, optimizer9)

###  Model 10
model10 = Model10()
criterion = nn.CrossEntropyLoss()
optimizer10 = optim.Adam(model10.parameters(), lr = 1e-3, weight_decay = 1e-4)
model10_params = sum(p.numel() for p in model10.parameters())
print(f'Nunber of parameter for model 10 is: {model10_params}')
train_test_model(model10, optimizer10)
# Out:
# Nunber of parameter for model 1 is: 4095
#  Train Loss: 1.5324, Test Loss: 1.5549
# Nunber of parameter for model 2 is: 8280
#  Train Loss: 0.3383, Test Loss: 0.3353
# Nunber of parameter for model 3 is: 9982
#  Train Loss: 0.2829, Test Loss: 0.2841
# Nunber of parameter for model 4 is: 15126
#  Train Loss: 0.2258, Test Loss: 0.2304
# Nunber of parameter for model 5 is: 16485
#  Train Loss: 0.2390, Test Loss: 0.2433
# Nunber of parameter for model 6 is: 20787
#  Train Loss: 0.1825, Test Loss: 0.1910
# Nunber of parameter for model 7 is: 26850
#  Train Loss: 0.1544, Test Loss: 0.1704
# Nunber of parameter for model 8 is: 36372
#  Train Loss: 0.1171, Test Loss: 0.1307
# Nunber of parameter for model 9 is: 59850
#  Train Loss: 0.0892, Test Loss: 0.1134
# Nunber of parameter for model 10 is: 74458
#  Train Loss: 0.0860, Test Loss: 0.1127

# %%
loss_train = []
for i in train_losses:
    loss_train.append(i.data.numpy().tolist())

loss_test = []
for i in test_losses:
    loss_test.append(i.data.numpy().tolist())

params = (model1_params,model2_params,model3_params,model4_params,
          model5_params,model6_params,model7_params,model8_params,
          model9_params,model10_params)

# %%
plt.figure(figsize=(10,5))
plt.scatter(params, loss_train, color = "r")
plt.scatter(params, loss_test, color = "b")
plt.title('Model Train and Test Loss Comparision')
plt.legend(['Train Loss', 'Test Loss'],loc='upper right')
plt.xlabel('Parameters')
plt.ylabel('Loss')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter(params, train_accuracies, color = "r")
plt.scatter(params, test_accuracies, color = "b")
plt.title('Model Loss Comparision')
plt.legend(['Train Loss', 'Test Loss'],loc='lower right')
plt.xlabel('Parameters')
plt.ylabel('Loss')
plt.show()
